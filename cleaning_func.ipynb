# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# tidyness issue - structural issues of dataframe, merging of dataframes
# Quality issues- inconsistency in dataframe

# %%
# pd.read_excel`("gun_data.xlsx")

# %%
pd.read_csv("U.S. Census Data.csv").T.head()
# Out:
#                                                      0   \
# Fact       Population estimates, July 1, 2016,  (V2016)
# Fact Note                                           NaN
# Alabama                                       4,863,300
# Alaska                                          741,894
# Arizona                                       6,931,071
#
#                                                           1   \
# Fact       Population estimates base, April 1, 2010,  (V2...
# Fact Note                                                NaN
# Alabama                                            4,780,131
# Alaska                                               710,249
# Arizona                                            6,392,301
#
#                                                           2   \
# Fact       Population, percent change - April 1, 2010 (es...
# Fact Note                                                NaN
# Alabama                                                1.70%
# ...

# %%
new_column = list(df.iloc[0,:])

# %%
df.columns = new_column
df_1 = df.iloc[2:,:]

# %%
df_1.reset_index(inplace = True)

# %%
df_1.rename(columns = {"index" : "Country_name"}).head()
# Out:
#   Country_name Population estimates, July 1, 2016,  (V2016)  \
# 0      Alabama                                    4,863,300
# 1       Alaska                                      741,894
# 2      Arizona                                    6,931,071
# 3     Arkansas                                    2,988,248
# 4   California                                   39,250,017
#
#   Population estimates base, April 1, 2010,  (V2016)  \
# 0                                          4,780,131
# 1                                            710,249
# 2                                          6,392,301
# 3                                          2,916,025
# 4                                         37,254,522
#
#   Population, percent change - April 1, 2010 (estimates base) to July 1, 2016,  (V2016)  \
# 0                                              1.70%
# 1                                              4.50%
# 2                                              8.40%
# ...

# %%
## we want to remove commas, % and dollar sign

# %%
# df_1.dropna(inplace = True)
df_1.head()
# Out:
#            Population estimates, July 1, 2016,  (V2016)  \
# Alabama                                       4,863,300
# Alaska                                          741,894
# Arizona                                       6,931,071
# Arkansas                                      2,988,248
# California                                   39,250,017
#
#            Population estimates base, April 1, 2010,  (V2016)  \
# Alabama                                             4,780,131
# Alaska                                                710,249
# Arizona                                             6,392,301
# Arkansas                                            2,916,025
# California                                         37,254,522
#
#            Population, percent change - April 1, 2010 (estimates base) to July 1, 2016,  (V2016)  \
# Alabama                                                 1.70%
# Alaska                                                  4.50%
# ...

# %%
df_1.columns
# Out:
# Index([                                                                                 'index',
#                                                  'Population estimates, July 1, 2016,  (V2016)',
#                                            'Population estimates base, April 1, 2010,  (V2016)',
#         'Population, percent change - April 1, 2010 (estimates base) to July 1, 2016,  (V2016)',
#                                                             'Population, Census, April 1, 2010',
#                                        'Persons under 5 years, percent, July 1, 2016,  (V2016)',
#                                                 'Persons under 5 years, percent, April 1, 2010',
#                                       'Persons under 18 years, percent, July 1, 2016,  (V2016)',
#                                                'Persons under 18 years, percent, April 1, 2010',
#                                   'Persons 65 years and over, percent,  July 1, 2016,  (V2016)',
# ...

# %%
columns_to_treat = ['Population estimates base, April 1, 2010,  (V2016)','Median household income (in 2015 dollars), 2011-2015',
    'Population, percent change - April 1, 2010 (estimates base) to July 1, 2016,  (V2016)']

# %%
df_2 = df_1[columns_to_treat]

# %%
df_2.head()
# Out:
#   Population estimates base, April 1, 2010,  (V2016)  \
# 0                                          4,780,131
# 1                                            710,249
# 2                                          6,392,301
# 3                                          2,916,025
# 4                                         37,254,522
#
#   Median household income (in 2015 dollars), 2011-2015  \
# 0                                           $43,623
# 1                                           $72,515
# 2                                           $50,255
# 3                                           $41,371
# 4                                           $61,818
#
#   Population, percent change - April 1, 2010 (estimates base) to July 1, 2016,  (V2016)
# 0                                              1.70%
# 1                                              4.50%
# 2                                              8.40%
# 3                                              2.50%
# ...

# %%
type(df_2[df_2.columns[0]][0])
# Out:
# str

# %%
df_2[df_2.columns[1]][0]
# Out:
# '$43,623 '

# %%
df_2[df_2.columns[2]][1]
# Out:
# '4.50%'

# %%
x = "4,780,131"
int(x.replace(",","").replace("$",""))
# Out:
# 4780131

# %%
y = '$43,623 '
int(y.replace("$","").strip().replace(",",""))
# Out:
# 43623

# %%
"$43623"
# Out:
# '$43623'

# %%
z = "4.50%"
z_ = float(z.replace("%",''))
round(z_,3)
float("{:.3f}".format(z_))
# Out:
# 4.5

# %%
"%" in z
# Out:
# True

# %%
"$" in y
# Out:
# True

# %%
"," in "$56,53,3.23"
# Out:
# True

# %%
def func_treat(row):
    if "%" in row:
        return float(row.replace("%",''))
    elif "$" in row:
        return int(row.replace("$","").strip().replace(",",""))
    elif "," in row:
        return int(row.replace(",","").replace("$",""))
    return row

# %%
df_2[columns_to_treat[0]][:4]
# Out:
# 0    4,780,131
# 1      710,249
# 2    6,392,301
# 3    2,916,025
# Name: Population estimates base, April 1, 2010,  (V2016), dtype: object

# %%
for columns in columns_to_treat:
    df_2[columns] = df_2[columns].apply(lambda y : func_treat(y))
# Out:
# C:\Users\Rotimi\AppData\Local\Temp\ipykernel_16424\1792808099.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2[columns] = df_2[columns].apply(lambda y : func_treat(y) )

# %%
df_2.head()
# Out:
#   Population estimates base, April 1, 2010,  (V2016)  \
# 0                                            4780131
# 1                                             710249
# 2                                            6392301
# 3                                            2916025
# 4                                           37254522
#
#   Median household income (in 2015 dollars), 2011-2015  \
# 0                                              43623
# 1                                              72515
# 2                                              50255
# 3                                              41371
# 4                                              61818
#
#   Population, percent change - April 1, 2010 (estimates base) to July 1, 2016,  (V2016)
# 0                                                1.7
# 1                                                4.5
# 2                                                8.4
# 3                                                2.5
# ...

# %%
df_2.shape[0]
# Out:
# 50

# %%
int("45247")
# Out:
# 45247
